                 [520, 86, 3299, 72, 170, 2864, 558, 662, 1489, 856, 1434 ],
                 [543, 2931, 448, 342, 2495, 239, 288, 1797, 1266, 1878 ],
                 [3295, 97, 199, 2859, 588, 692, 1637, 858, 1339 ],
                 [3227, 3206, 446, 2750, 2649, 4617, 2417, 1882 ],
                 [102, 2791, 486, 590, 1535, 8700, 1441 ],
                 [2770, 389, 497, 1514, 888, 1543 ],
                 [2314, 2213, 4181, 2105, 1446 ],
                 [112, 1972, 994, 1345 ],
                 [2076, 1057, 1408 ],
                 [2328, 2986 ],
                 [962 ]]

  qtdePontos = len(matrizCidades)
  print(qtdePontos)


  def __init__(self, qtdePontos, matrizCidades):
    self.qtdePontos = qtdePontos
    self.matrizCidades = matrizCidades
    


  def distancias(self):
    qtde = qtdePontos
    cidade = np.zeros((qtde,qtde))
    print(len(cidade))
    for i in range(0,qtde):
      for j in range(0,qtde):
        if(i==j):
          cidade[i][j] = 0
        else:
          cidade[i][j] = matrizCidades[i][j]
    return cidade[i][j]

class Individuos:
  def __init__(self, tamanhoPopulacao, qtdePontos):
      self.tamanhoPopulacao = tamanhoPopulacao
      self.qtdePontos = qtdePontos

  def gerarCromossomo(self):
    cromossomo = []
    populacao = []
    qtdePontos = self.qtdePontos
    tamanhoPopulacao = self.tamanhoPopulacao
    x = 1
    for x in range(tamanhoPopulacao):
      while len(cromossomo) != qtdePontos:
        for i in range(qtdePontos):
          for j in range(qtdePontos):
            if matrizCidades[i][j] not in cromossomo:
                cromossomo.append(matrizCidades[i][j])
      populacao.append(cromossomo)
      cromossomo = []
      self.populacao = populacao
      return self.populacao

  def gerarFitness(self, populacao, matrizCidades):
      fitness = []
      qtdePontos = self.qtdePontos
      tamanhoPopulacao = self.tamanhoPopulacao
      for i in range(tamanhoPopulacao):
        aux = []
        nota = 0
        x = 0
        y = 0
        aux = populacao[i]
        for j in range(qtdePontos-1):
          x = aux[j]
          if(j < qtdePontos):
            y = aux[j+1]
          else:
            y = -1
          if(y > 0):
            nota = matrizCidades[x-1][y-1]
        fitness.append(nota)
      self.fitness = fitness
      return self.fitness

  def ordenarPopulacoes(self, populacao, matrizCidades):
      aux = []
      if(len(populacao) == 0):
        populacao = self.gerarCromossomo()
      fitness = self.gerarFitness(populacao, matrizCidades)
      aux = list(zip(fitness,populacao))
      tupla = []
      tupla = sorted(aux, reverse=False)
      self.listaOrdenada = tupla
      return self.listaOrdenada

  def crossover(self, populacao, matrizCidades):
    novaPopulacao = []
    if(len(populacao) == 0):
      populacao = self.geraCromossomo()
    qtdePontos = self.qtdePontos
    tamanhoPopulacao = self.tamanhoPopulacao
    tupla = self.ordenarPopulacoes(populacao, matrizCidades)
    for i in range(0, tamanhoPopulacao, 2):
      paiUm = []
      paiDois = []
      cromossomoFilho = []
      filhoUm = []
      filhoDois = []
      tupla = paiUm[i][1]

      if(i < tamanhoPopulacao-1):
        tupla = paiUm[i+1][1]
      else:
        pai2 = tupla[-1][1]
      for x in range(qtdePontos):
        if random() < 0.7:
          cromossomoFilho.append("0")
        else:
          cromossomoFilho.append("1")


        for j in range(qtdePontos):
          if(cromossomoFilho == "1"):
              filhoUm.append(paiUm[j])
          else:
            filhoUm.append(0)
        for j in range(qtdePontos):
          z = 0
          if(filhoUm[j] == "0"):
            while(z != qtdePontos):
              if paiDois not in filhoUm: 
                filhoUm[j] = paiDois[z]
                z = qtdePontos
              else:
                z = z + 1
          filhoUm = self.mutacao(filhoUm)

          for j in range(qtdePontos):
            if(cromossomoFilho == "1"):
              filhoDois.append(paiDois[j])
            else:
              filhoDois.append(0)
            for j in range(qtdePontos):
              z = 0
              if(filhoDois[j] == "0"):
                while(z != qtdePontos):
                  if paiUm not in filhoDois: 
                    filhoDois[j] = paiUm[z]
                    z = qtdePontos
                  else:
                    z = z + 1
                  filhoDois = self.mutacao(filhoDois)
            novaPopulacao.append(filhoUm)
            novaPopulacao.append(filhoDois)
            listaOrdenada = self.ordenarPopulacoes(novaPopulacao, matrizCidades)
            self.listaOrdenada = listaOrdenada
            return listaOrdenada

    def mutacao(self, filho):
      taxaMutacao = random()
      qtdePontos = self.qtdePontos
      if taxaMutacao < 0.01:
        indiceUm = randint(0, (qtdePontos-1))
        indiceDois = randint(0, (qtdePontos-1))
        auxUm = filho[indiceUm]
        auxDois = filho[indiceDois]
        filho[indiceUm] = auxDois
        filho[indiceDois] = auxUm
      return filho
# Out:
# 57

# %%
class AlgoritimoGenetico():
  
  def __init__(self, tamanhoPopulacao, qtdePontos, geracoes):
    self.tamanhoPopulacao = tamanhoPopulacao
    self.qtdePontos = qtdePontos
    self.geracoes = geracoes
    self.melhores = []

  def resolver(self):
    tamanhoPopulacao = self.tamanhoPopulacao
    qtdePontos = self.qtdePontos
    geracoes = self.geracoes
    cidade = Cidade(qtdePontos, matrizCidades)
  #  cidade = cidade.distancias()
    individuo = Individuos(tamanhoPopulacao, qtdePontos)
    populacao = individuo.gerarCromossomo()
    pop = individuo.crossover(populacao, matrizCidades)
    menor = 10000
    melhor = [0][0]
    for i in range(geracoes):
      populacao = []
      for j in range(tamanhoPopulacao):
        populacao.append(pop[j][1])
        resultado = individuo.crossover(populacao, matrizCidades)
        if(melhor <= menor):
          melhor = resultado[0][0]
          self.melhores.append(melhor)
          pop = resultado
    return resultado

tamanhoPopulacao = 57
geracoes = 2
qtdePontos = 58

algoritmoGenetico = AlgoritimoGenetico(tamanhoPopulacao, qtdePontos, geracoes)
teste = algoritmoGenetico.resolver()
print("Resultado: ", teste[0])
plt.plot(algoritmoGenetico.melhores)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-d44d7acc49f2> in <module>()
#      35
#      36 algoritmoGenetico = AlgoritimoGenetico(tamanhoPopulacao, qtdePontos, geracoes)
# ---> 37 teste = algoritmoGenetico.resolver()
#      38 print("Resultado: ", teste[0])
#      39 plt.plot(algoritmoGenetico.melhores)
#
# <ipython-input-6-d44d7acc49f2> in resolver(self)
#      15   #  cidade = cidade.distancias()
#      16     individuo = Individuos(tamanhoPopulacao, qtdePontos)
# ---> 17     populacao = individuo.gerarCromossomo()
#      18     pop = individuo.crossover(populacao, matrizCidades)
#      19     menor = 10000
#
# <ipython-input-5-922de722e3ce> in gerarCromossomo(self)
#     107         for i in range(qtdePontos):
#     108           for j in range(qtdePontos):
# --> 109             if matrizCidades[i][j] not in cromossomo:
# ...
